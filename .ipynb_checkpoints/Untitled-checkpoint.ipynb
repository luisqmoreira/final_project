# %%
import pandas as pd
import numpy as np
import plotly_express as px
import georasters as gr
from osgeo import gdal

# %%
data = pd.read_csv('/Users/luismoreira/Desktop/Final_project/final_project/table.csv')

# %%
data.drop('Unnamed: 0', axis=1,inplace=True)

# %%
data.drop('esp_or_not', axis=1,inplace=True)

# %%
data.head()
# Out:
#    index long_position_solar lat_position_solar  value_phov  \
# 0     40    (-9.604, -9.512]   (39.022, 39.075]   1555.2340
# 1    133    (-9.512, -9.423]     (38.646, 38.7]   1650.0613
# 2    141    (-9.512, -9.423]   (39.075, 39.129]   1545.9958
# 3    142    (-9.512, -9.423]   (39.129, 39.183]   1544.7921
# 4    232    (-9.423, -9.335]   (38.592, 38.646]   1666.3787
#
#   long_position_topo lat_position_topo  elevation     long_position  \
# 0     (-9.696, -9.6]  (39.306, 39.384]   7.837209  (-9.683, -9.587]
# 1     (-9.6, -9.508]  (38.758, 38.837]   7.181818  (-9.587, -9.496]
# 2     (-9.6, -9.508]  (39.384, 39.462]  21.193548  (-9.587, -9.496]
# 3     (-9.6, -9.508]  (39.462, 39.541]   4.220000  (-9.587, -9.496]
# 4   (-9.508, -9.415]   (38.68, 38.758]  67.480836  (-9.496, -9.404]
#
#        lat_position     value  lat_leftend  lat_rightend  long_leftend  \
# 0  (39.311, 39.389]  6.416667       39.311        39.389        -9.696
# ...

# %%
data['Address'].value_counts()
# Out:
# Portugal                                                                                             62
# Alcácer do Sal e Santa Susana, Alcácer do Sal, Setúbal, Portugal                                      4
# Malpica do Tejo, Castelo Branco, Portugal                                                             3
# Samora Correia, Benavente, Santarém, Portugal                                                         3
# Viana do Castelo, 4900-999, Portugal                                                                  3
#                                                                                                      ..
# Monte de São Domingos, EN 5-2, Morcela Velha, Torrão, Alcácer do Sal, Setúbal, 7595-125, Portugal     1
# Herdade da Quinta de Cima, Torrão, Alcácer do Sal, Setúbal, Portugal                                  1
# EM 525, Figueira dos Cavaleiros, Ferreira do Alentejo, Beja, Portugal                                 1
# ...

# %%
data[data['Address'] == 'Portugal']
# Out:
#       index long_position_solar lat_position_solar  value_phov  \
# 0        40    (-9.604, -9.512]   (39.022, 39.075]   1555.2340
# 1       133    (-9.512, -9.423]     (38.646, 38.7]   1650.0613
# 2       141    (-9.512, -9.423]   (39.075, 39.129]   1545.9958
# 3       142    (-9.512, -9.423]   (39.129, 39.183]   1544.7921
# 4       232    (-9.423, -9.335]   (38.592, 38.646]   1666.3787
# ...     ...                 ...                ...         ...
# 225    1060    (-8.717, -8.628]   (40.095, 40.149]   1519.0809
# 226    1062    (-8.717, -8.628]   (40.202, 40.256]   1520.6697
# 288    1161     (-8.628, -8.54]   (40.149, 40.202]   1508.8430
# 628    1710     (-8.098, -8.01]   (37.412, 37.465]   1667.3054
# 1068   2412     (-7.48, -7.392]   (37.519, 37.573]   1657.7053
#
#      long_position_topo lat_position_topo  elevation     long_position  \
# 0        (-9.696, -9.6]  (39.306, 39.384]   7.837209  (-9.683, -9.587]
# ...

# %%
data.columns
# Out:
# Index(['index', 'long_position_solar', 'lat_position_solar', 'value_phov',
#        'long_position_topo', 'lat_position_topo', 'elevation', 'long_position',
#        'lat_position', 'value', 'lat_leftend', 'lat_rightend', 'long_leftend',
#        'long_rightend', 'coordinates', 'Address'],
#       dtype='object')

# %%
data.drop(['long_position_solar', 'lat_position_solar','long_position_topo', 'lat_position_topo'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['index', 'value_phov', 'elevation', 'long_position', 'lat_position',
#        'value', 'lat_leftend', 'lat_rightend', 'long_leftend', 'long_rightend',
#        'coordinates', 'Address'],
#       dtype='object')

# %%
data.columns = ['index', 'Phov', 'Elevation', 'long_bins', 'lat_bins',
       'Inclination', 'lat_leftend', 'lat_rightend', 'long_leftend', 'long_rightend',
       'Coordinates', 'Address']

# %%
data[data['Address'] == 'Portugal'].index
# Out:
# Int64Index([   0,    1,    2,    3,    4,    6,    7,    8,    9,   10,   11,
#               18,   19,   20,   21,   32,   33,   47,   48,   64,   65,   66,
#               67,   68,   86,   87,   91,   92,   93,   94,   95,  116,  117,
#              118,  119,  122,  127,  128,  129,  130,  131,  132,  133,  134,
#              138,  139,  140,  165,  166,  167,  168,  169,  170,  171,  222,
#              223,  224,  225,  226,  288,  628, 1068],
#            dtype='int64')

# %%
a = data.iloc[[   0,    1,    2,    3,    4,    6,    7,    8,    9,   10,   11,
              18,   19,   20,   21,   32,   33,   47,   48,   64,   65,   66,
              67,   68,   86,   87,   91,   92,   93,   94,   95,  116,  117,
             118,  119,  122,  127,  128,  129,  130,  131,  132,  133,  134,
             138,  139,  140,  165,  166,  167,  168,  169,  170,  171,  222,
             223,  224,  225,  226,  288,  628, 1068]]['Address'] == 'Portugal'
a.value_counts()
# Out:
# True    62
# Name: Address, dtype: int64

# %%
data.drop([   0,    1,    2,    3,    4,    6,    7,    8,    9,   10,   11,
              18,   19,   20,   21,   32,   33,   47,   48,   64,   65,   66,
              67,   68,   86,   87,   91,   92,   93,   94,   95,  116,  117,
             118,  119,  122,  127,  128,  129,  130,  131,  132,  133,  134,
             138,  139,  140,  165,  166,  167,  168,  169,  170,  171,  222,
             223,  224,  225,  226,  288,  628, 1068], inplace=True)

# %%
data_clean = data.copy()

# %%
data_clean.reset_index(inplace=True)

# %%
data_clean.head()
# Out:
#    level_0  index       Phov   Elevation         long_bins          lat_bins  \
# 0        5    233  1649.0002  155.476274  (-9.496, -9.404]  (38.767, 38.845]
# 1       12    332  1654.1453   83.547421  (-9.404, -9.312]  (38.689, 38.767]
# 2       13    333  1634.1395  186.357420  (-9.404, -9.312]  (38.767, 38.845]
# 3       14    334  1634.9681  139.481740  (-9.404, -9.312]  (38.845, 38.922]
# 4       15    335  1611.8870  122.346542  (-9.404, -9.312]    (38.922, 39.0]
#
#    Inclination  lat_leftend  lat_rightend  long_leftend  long_rightend  \
# 0     6.416667       38.767        38.845        -9.508         -9.415
# 1     7.000000       38.689        38.767        -9.415         -9.323
# 2     6.777778       38.767        38.845        -9.415         -9.323
# 3     5.777778       38.845        38.922        -9.415         -9.323
# 4     6.000000       38.922        39.000        -9.415         -9.323
#
#      Coordinates                                            Address
# ...

# %%
px.scatter_mapbox(data_clean, lat='lat_leftend', lon='long_leftend', zoom=4, mapbox_style="carto-positron", color = 'Inclination')

# %%
px.scatter_mapbox(data_clean, lat='lat_leftend', lon='long_leftend', zoom=4, mapbox_style="carto-positron", color = 'Phov')

# %%
px.scatter_mapbox(data_clean, lat='lat_leftend', lon='long_leftend', zoom=4, mapbox_style="carto-positron", color = 'Elevation')

# %%
districts = ['Aveiro', 
             'Beja', 
             'Braga', 
             'Bragança', 
             'Castelo_Branco', 
             'Coimbra',
             'Évora',
             'Faro',
             'Guarda',
             'Leiria',
             'Lisboa',
             'Portalegre',
             'Porto',
             'Santarém',
             'Setúbal',
             'Viana_do_Castelo',
             'Vila_Real',
             'Viseu']
district = []

def find_district(row):
    
    for item  in data_clean[row].split():
        if item in districts:
            return district.append(item)
        else:
            continue

# %%
#data_clean['Address'].apply(lambda x : x.split()[])
data_clean.head()
# Out:
#    level_0  index       Phov   Elevation         long_bins          lat_bins  \
# 0        5    233  1649.0002  155.476274  (-9.496, -9.404]  (38.767, 38.845]
# 1       12    332  1654.1453   83.547421  (-9.404, -9.312]  (38.689, 38.767]
# 2       13    333  1634.1395  186.357420  (-9.404, -9.312]  (38.767, 38.845]
# 3       14    334  1634.9681  139.481740  (-9.404, -9.312]  (38.845, 38.922]
# 4       15    335  1611.8870  122.346542  (-9.404, -9.312]    (38.922, 39.0]
#
#    Inclination  lat_leftend  lat_rightend  long_leftend  long_rightend  \
# 0     6.416667       38.767        38.845        -9.508         -9.415
# 1     7.000000       38.689        38.767        -9.415         -9.323
# 2     6.777778       38.767        38.845        -9.415         -9.323
# 3     5.777778       38.845        38.922        -9.415         -9.323
# 4     6.000000       38.922        39.000        -9.415         -9.323
#
#      Coordinates                                            Address
# ...

# %%
for i in range(len(data_clean['Address'])):
    print(type(data_clean['Address'].iloc[i]))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
clean = []
for item in list(data_clean['Address']):
    
    clean.append(item.replace(',','').replace('Vila Real', 'Vila_Real').replace('Viana do Castelo', 'Viana_do_Castelo').replace('Castelo Branco', 'Castelo_Branco').split())

# %%
dist_data = []
for lis in clean:
    for item in districts:
        if item in lis:
            dist_data.append(item)
        else:
            continue
# Out:
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Leiria
# Leiria
# Setúbal
# Setúbal
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Leiria
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Leiria
# Leiria
# Leiria
# Porto
# Leiria
# Porto
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Leiria
# Leiria
# Leiria
# Leiria
# Leiria
# Faro
# Faro
# Faro
# Setúbal
# Setúbal
# Porto
# Setúbal
# Setúbal
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Lisboa
# Santarém
# Leiria
# Leiria
# Leiria
# Leiria
# Leiria
# Leiria
# Leiria
# Leiria
# Viana_do_Castelo
# Viana_do_Castelo
# Faro
# Faro
# Faro
# Faro
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Setúbal
# Santarém
# Santarém
# Santarém
# Lisboa
# Lisboa
# Santarém
# Santarém
# ...

# %%
for item in districts:
    if item in pd.Series(dist_data).value_counts():
        continue
    else:
        print(item)
# Out:
# Castelo Branco
# Viana do Castelo
# Vila Real

# %%
pd.Series(dist_data).value_counts()
# Out:
# Beja                144
# Évora               105
# Santarém             98
# Portalegre           92
# Castelo_Branco       87
# Faro                 86
# Guarda               84
# Setúbal              83
# Bragança             75
# Viseu                73
# Vila_Real            66
# Coimbra              66
# Porto                52
# Leiria               51
# Lisboa               46
# Braga                42
# Aveiro               39
# Viana_do_Castelo     37
# dtype: int64

# %%
data_clean[(data_clean['lat_leftend'] > 41.32) & (data_clean['lat_leftend'] < 41.334) & (data_clean['long_leftend'] < -7.745) & (data_clean['long_leftend'] >  -7.765)]['Address']
# Out:
# 875    Outeiro, Borbela e Lamas de Olo, Vila Real, 50...
# Name: Address, dtype: object

# %%
#clean

# %%
data_clean.sha
# Out:
# (1313, 13)

# %% [markdown]
# # Plotly

# %%
import plotly.graph_objects as go

import pandas as pd

# Read data from a csv
z_data = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/api_docs/mt_bruno_elevation.csv')

fig = go.Figure(data=[go.Surface(z=z_data.values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
z_data
# Out:
#     Unnamed: 0          0           1           2          3          4  \
# 0            0  27.809850   49.619360   83.080670  116.66320  130.41400
# 1            1  27.719660   48.550220   65.213740   95.27666  116.99640
# 2            2  30.426700   33.477520   44.809530   62.47495   77.43523
# 3            3  16.665490   30.108600   39.969520   44.12225   59.57512
# 4            4   8.815617   18.351600    8.658275   27.58590   48.62691
# 5            5   6.628881   10.413390   24.819390   26.08952   30.16050
# 6            6  21.839750    6.639270   18.970850   32.89204   43.15014
# 7            7  53.343030   26.797970    6.639270   10.88787   17.20440
# 8            8  25.667850   63.057170   22.141400   17.07400   41.74483
# 9            9  12.827000   69.205540   46.762930   13.96517   33.88744
# 10          10   0.000000   68.663960   59.043500   33.35762   47.45282
# 11          11   0.000000   95.174990   80.038180   59.89862   39.58476
# ...

# %%
topo = gr.from_file('/Users/luismoreira/dem.tif')

# %%
topo = topo.to_pandas()

# %%
topo_filtered = topo[topo['value'] >= 0]

# %%
topo_experiment = topo_filtered.reset_index().head(50)

# %%
testing = topo_experiment.drop(['index', 'row', 'col'], axis = 1)

# %%
#testing.columns = ['z', 'x', 'y']
testing.head()
# Out:
#    value         x       y
# 0      0 -7.236984  43.999
# 1      1 -7.234623  43.999
# 2      2 -7.232262  43.999
# 3      2 -7.229902  43.999
# 4      3 -7.227541  43.999

# %%
z_test = testing['z']

# %%
#fig = go.Figure(data=[go.Surface(z=z_data.values)])

x, y = testing['x'], testing['y']
z = testing['value']
fig = go.Figure(data=[go.Surface(z=z, x=x, y=y)])
fig.update_layout(title='Test', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
testing
# Out:
#     value         x          y
# 0       0 -7.236984  43.999000
# 1       1 -7.234623  43.999000
# 2       2 -7.232262  43.999000
# 3       2 -7.229902  43.999000
# 4       3 -7.227541  43.999000
# 5       4 -7.225180  43.999000
# 6       6 -7.222820  43.999000
# 7       7 -7.220459  43.999000
# 8      10 -7.218098  43.999000
# 9      13 -7.215738  43.999000
# 10     15 -7.213377  43.999000
# 11     17 -7.211016  43.999000
# 12     19 -7.208656  43.999000
# 13     19 -7.206295  43.999000
# 14     16 -7.203934  43.999000
# 15     10 -7.201574  43.999000
# 16      1 -7.199213  43.999000
# 17      1 -7.236984  43.996639
# 18      4 -7.234623  43.996639
# 19      5 -7.232262  43.996639
# 20      6 -7.229902  43.996639
# 21      7 -7.227541  43.996639
# 22      8 -7.225180  43.996639
# 23      9 -7.222820  43.996639
# 24     11 -7.220459  43.996639
# 25     13 -7.218098  43.996639
# 26     16 -7.215738  43.996639
# 27     18 -7.213377  43.996639
# 28     21 -7.211016  43.996639
# ...

# %%
fig = go.Figure(data=[go.Surface(z=testing.set_index('y').values)])

fig.update_layout(title='Mt Bruno Elevation', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))

fig.show()

# %%
testing.iplot(kind = 'surface')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/mg/hz10g1l14916bvkqvy7r1fg40000gn/T/ipykernel_65836/1512717439.py in <module>
# ----> 1 testing.iplot(kind = 'surface')
#
# /opt/anaconda3/envs/solar/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'

# %%
testing
# Out:
#     value         x          y
# 0       0 -7.236984  43.999000
# 1       1 -7.234623  43.999000
# 2       2 -7.232262  43.999000
# 3       2 -7.229902  43.999000
# 4       3 -7.227541  43.999000
# 5       4 -7.225180  43.999000
# 6       6 -7.222820  43.999000
# 7       7 -7.220459  43.999000
# 8      10 -7.218098  43.999000
# 9      13 -7.215738  43.999000
# 10     15 -7.213377  43.999000
# 11     17 -7.211016  43.999000
# 12     19 -7.208656  43.999000
# 13     19 -7.206295  43.999000
# 14     16 -7.203934  43.999000
# 15     10 -7.201574  43.999000
# 16      1 -7.199213  43.999000
# 17      1 -7.236984  43.996639
# 18      4 -7.234623  43.996639
# 19      5 -7.232262  43.996639
# 20      6 -7.229902  43.996639
# 21      7 -7.227541  43.996639
# 22      8 -7.225180  43.996639
# 23      9 -7.222820  43.996639
# 24     11 -7.220459  43.996639
# 25     13 -7.218098  43.996639
# 26     16 -7.215738  43.996639
# 27     18 -7.213377  43.996639
# 28     21 -7.211016  43.996639
# ...

# %%
testing.set_index('y')
# Out:
#            value         x
# y
# 43.999000      0 -7.236984
# 43.999000      1 -7.234623
# 43.999000      2 -7.232262
# 43.999000      2 -7.229902
# 43.999000      3 -7.227541
# 43.999000      4 -7.225180
# 43.999000      6 -7.222820
# 43.999000      7 -7.220459
# 43.999000     10 -7.218098
# 43.999000     13 -7.215738
# 43.999000     15 -7.213377
# 43.999000     17 -7.211016
# 43.999000     19 -7.208656
# 43.999000     19 -7.206295
# 43.999000     16 -7.203934
# 43.999000     10 -7.201574
# 43.999000      1 -7.199213
# 43.996639      1 -7.236984
# 43.996639      4 -7.234623
# 43.996639      5 -7.232262
# 43.996639      6 -7.229902
# 43.996639      7 -7.227541
# 43.996639      8 -7.225180
# 43.996639      9 -7.222820
# 43.996639     11 -7.220459
# 43.996639     13 -7.218098
# 43.996639     16 -7.215738
# 43.996639     18 -7.213377
# 43.996639     21 -7.211016
# 43.996639     22 -7.208656
# 43.996639     23 -7.206295
# 43.996639     22 -7.203934
# 43.996639     17 -7.201574
# ...

# %% [markdown]
# # Continued
